# %%
import numpy as np
import pandas as pd
import pystac

# %%
# Set up pystac to read/write from S3

aws_profile = "edge-admin"

from urllib.parse import urlparse
import boto3
from pystac import Link
from pystac.stac_io import DefaultStacIO, StacIO
from typing import Union, Any


class CustomStacIO(DefaultStacIO):
    def __init__(self):
        boto3.setup_default_session(profile_name=aws_profile)
        self.s3 = boto3.resource("s3")
        super().__init__()

    def read_text(self, source: Union[str, Link], *args: Any, **kwargs: Any) -> str:
        parsed = urlparse(source)
        if parsed.scheme == "s3":
            bucket = parsed.netloc
            key = parsed.path[1:]

            obj = self.s3.Object(bucket, key)
            return obj.get()["Body"].read().decode("utf-8")
        else:
            return super().read_text(source, *args, **kwargs)

    def write_text(
        self, dest: Union[str, Link], txt: str, *args: Any, **kwargs: Any
    ) -> None:
        parsed = urlparse(dest)
        if parsed.scheme == "s3":
            bucket = parsed.netloc
            key = parsed.path[1:]
            self.s3.Object(bucket, key).put(Body=txt, ContentEncoding="utf-8")
        else:
            super().write_text(dest, txt, *args, **kwargs)


StacIO.set_default(CustomStacIO)

# %% [markdown]
# ## Load the catalog
# This will create a Catalog object, but will not load the metadata items yet.

# %%
catalog = pystac.Catalog.from_file('s3://aodn-data-index-nonproduction/catalog.json')
catalog
# Out:
# <Catalog id=data_index>

# %% [markdown]
# ## Get all s3 paths for files in a collection
# Querying by metadata uuid

# %%
uuid = "279a50e3-21a5-4590-85a0-71f963efab82"
collection = catalog.get_child(uuid, recursive=True)
collection
# Out:
# <Collection id=279a50e3-21a5-4590-85a0-71f963efab82>

# %%
s3_paths = [item.assets['data'].href for item in collection.get_all_items()]
s3_paths
# Out:
# ['s3://imos-data/IMOS/ANMN/SA/SAM1DS/gridded_timeseries/IMOS_ANMN-SA_TZ_20081211_SAM1DS_FV02_TEMP-gridded-timeseries_END-20090604_C-20220622.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM2CP/gridded_timeseries/IMOS_ANMN-SA_TZ_20081020_SAM2CP_FV02_TEMP-gridded-timeseries_END-20100317_C-20220622.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM3MS/gridded_timeseries/IMOS_ANMN-SA_TZ_20110222_SAM3MS_FV02_TEMP-gridded-timeseries_END-20130630_C-20220622.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM4CY/gridded_timeseries/IMOS_ANMN-SA_TZ_20090205_SAM4CY_FV02_TEMP-gridded-timeseries_END-20100316_C-20220622.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM5CB/gridded_timeseries/IMOS_ANMN-SA_TZ_20090206_SAM5CB_FV02_TEMP-gridded-timeseries_END-20241119_C-20250125.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM6IS/gridded_timeseries/IMOS_ANMN-SA_TZ_20090205_SAM6IS_FV02_TEMP-gridded-timeseries_END-20090602_C-20220622.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM7DS/gridded_timeseries/IMOS_ANMN-SA_TZ_20091215_SAM7DS_FV02_TEMP-gridded-timeseries_END-20140312_C-20220921.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/gridded_timeseries/IMOS_ANMN-SA_TZ_20090602_SAM8SG_FV02_TEMP-gridded-timeseries_END-20240924_C-20250125.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAMUSG/gridded_timeseries/IMOS_ANMN-SA_TZ_20190727_SAMUSG_FV02_TEMP-gridded-timeseries_END-20241104_C-20250125.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/gridded_timeseries/IMOS_ANMN-SA_TZ_20190624_VBM100_FV02_TEMP-gridded-timeseries_END-20231206_C-20240516.nc']

# %% [markdown]
# This can also work with higher level metadata items, containing several collections.

# %%
uuid = "6c981d98-d7fb-4120-9ebe-347ef1188ae0"
collection = catalog.get_child(uuid, recursive=True)
collection
# Out:
# <Collection id=6c981d98-d7fb-4120-9ebe-347ef1188ae0>

# %%
s3_paths = [item.assets['data'].href for item in collection.get_items(recursive=True)]
len(s3_paths)
# Out:
# 2337

# %% [markdown]
# ## Identify duplicate files

# %%
# Get all items in ANMN collection
collection = catalog.get_child("f9c151bd-d95b-4af6-8cb7-21c05b7b383b", recursive=True)
items = collection.get_items(recursive=True)
# Convert to DataFrame
df = pd.DataFrame.from_dict(
    {
        item: item.properties | {"collection": item.collection_id}
        for item in items
    },
    orient="index",
)

# %%
# Find duplicated items
duplicates = df[~df['toolbox_input_file'].isna()]  # Only consider items with toolbox_input_file
duplicates = duplicates[
    duplicates.duplicated(
        [
            'deployment_code',
            'collection',
            'file_version',
            'instrument_serial_number',
            'toolbox_input_file',
        ],
        keep=False,
    )
]
duplicates
# Out:
#                                                         Conventions  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  CF-1.6,IMOS-1.4
# ...                                                             ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  CF-1.6,IMOS-1.4
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  CF-1.6,IMOS-1.4
#
#                                                                                       acknowledgement  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  Any users of IMOS data are required to clearly...
# ...                                                                                               ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Any users of IMOS data are required to clearly...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Any users of IMOS data are required to clearly...
#
#                                                                author  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  de Oliveira, Hugo
# ...                                                               ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  de Oliveira, Hugo
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  de Oliveira, Hugo
#
#                                                                author_email  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  hugo.oliveira@sa.gov.au
# ...                                                                     ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  hugo.oliveira@sa.gov.au
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  hugo.oliveira@sa.gov.au
#
#                                                                                              citation  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  The citation in a list of references is: "IMOS...
# ...                                                                                               ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  The citation in a list of references is: "IMOS...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  The citation in a list of references is: "IMOS...
#
#                                                    contributor_email  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...               NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...               NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...               NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...               NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...               NaN
# ...                                                              ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...               NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...               NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...               NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...               NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...               NaN
#
#                                                    contributor_name  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...              NaN
# ...                                                             ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
#
#                                                    contributor_role  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...              NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...              NaN
# ...                                                             ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...              NaN
#
#                                                                              data_centre  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  Australian Ocean Data Network (AODN)
# ...                                                                                  ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Australian Ocean Data Network (AODN)
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  Australian Ocean Data Network (AODN)
#
#                                                    data_centre_email  ...  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...  info@aodn.org.au  ...
# ...                                                              ...  ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  info@aodn.org.au  ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...  info@aodn.org.au  ...
#
#                                                    distribution_statement  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                    NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                    NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                    NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                    NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                    NaN
# ...                                                                   ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                    NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                    NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                    NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                    NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                    NaN
#
#                                                    project_acknowledgement  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                     NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                     NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                     NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                     NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                     NaN
# ...                                                                    ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                     NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                     NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                     NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                     NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                     NaN
#
#                                                    instrument_burst_duration  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                       NaN
# ...                                                                      ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
#
#                                                    instrument_burst_interval  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                       NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                       NaN
# ...                                                                      ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                       NaN
#
#                                                    instrument_beam_angle  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                   NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                   NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                   NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                   NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                   NaN
# ...                                                                  ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                   NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                   NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                   NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                   NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                   NaN
#
#                                                    quality_control_set  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                 NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                 NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                 NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                 NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                 NaN
# ...                                                                ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                 NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                 NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                 NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                 NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                 NaN
#
#                                                     instrument_average_interval  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                          NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                          NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                          NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                          NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                          NaN
# ...                                                                         ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                          NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                          NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                          NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                          NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                          NaN
#
#                                                     netcdf_group_name  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...                NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...                NaN
# ...                                                               ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...                NaN
#
#                                                     toolbox_parser  \
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...             NaN
# ...                                                            ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
#
#                                                     rejected_files
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...             NaN
# <Item id=IMOS_ANMN_SA_CJ2_Biogeochem_profiles_I...             NaN
# ...                                                            ...
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
# <Item id=IMOS_ANMN_SA_VBM100_Biogeochem_profile...             NaN
#
# [202 rows x 93 columns]

# %%
[
    item.assets['data'].href
    for item in df.index
    if item.assets['data'].href.startswith(
        's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_2024'
    )
]
# Out:
# ['s3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240407T063700Z_VBM100_FV01_Profile-SBE19plus_C-20240905T023025Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023500Z_VBM100_FV01_Profile-SBE19plus_C-20241015T003538Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023500Z_VBM100_FV01_Profile-SBE19plus_C-20250116T062051Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023700Z_VBM100_FV01_Profile-SBE19plus_C-20241015T002644Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023700Z_VBM100_FV01_Profile-SBE19plus_C-20250116T062050Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20241021T222800Z_VBM100_FV01_Profile-SBE19plus_C-20250113T230053Z.nc']

# %%
[dup.assets['data'].href for dup in duplicates.index]
# Out:
# ['s3://imos-data/IMOS/ANMN/SA/CJ1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T081400Z_CJ1_FV01_Profile-SBE19plus_C-20240905T020756Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T081400Z_CJ1_FV01_Profile-SBE19plus_C-20241220T054611Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T060400Z_CJ2_FV01_Profile-SBE19plus_C-20240905T020757Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T060400Z_CJ2_FV01_Profile-SBE19plus_C-20241220T054612Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T135900Z_CJ2_FV01_Profile-SBE19plus_C-20241009T025854Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T135900Z_CJ2_FV01_Profile-SBE19plus_C-20241220T055637Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ3/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T040600Z_CJ3_FV01_Profile-SBE19plus_C-20240905T020758Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ3/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T040600Z_CJ3_FV01_Profile-SBE19plus_C-20241220T054613Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ3/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T123400Z_CJ3_FV01_Profile-SBE19plus_C-20241009T025856Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/CJ3/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T123400Z_CJ3_FV01_Profile-SBE19plus_C-20241220T055639Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA06N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T004200Z_GA06N_FV01_Profile-SBE19plus_C-20240205T004346Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA06N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T004200Z_GA06N_FV01_Profile-SBE19plus_C-20241220T061605Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA06N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T000300Z_GA06N_FV01_Profile-SBE19plus_C-20240905T020759Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA06N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T000300Z_GA06N_FV01_Profile-SBE19plus_C-20241220T054615Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA07M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T023900Z_GA07M_FV01_Profile-SBE19plus_C-20240205T004347Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA07M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T023900Z_GA07M_FV01_Profile-SBE19plus_C-20241220T061606Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA07M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T021200Z_GA07M_FV01_Profile-SBE19plus_C-20240905T020800Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA07M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T021200Z_GA07M_FV01_Profile-SBE19plus_C-20241220T054616Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08L/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T043000Z_GA08L_FV01_Profile-SBE19plus_C-20241015T014859Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08L/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T043000Z_GA08L_FV01_Profile-SBE19plus_C-20241220T061608Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08L/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T075800Z_GA08L_FV01_Profile-SBE19plus_C-20240205T004348Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08L/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T075800Z_GA08L_FV01_Profile-SBE19plus_C-20241015T014435Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08L/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T041900Z_GA08L_FV01_Profile-SBE19plus_C-20240905T020801Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08L/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T041900Z_GA08L_FV01_Profile-SBE19plus_C-20241220T054618Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T202100Z_GA08N_FV01_Profile-SBE19plus_C-20240205T004349Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T202100Z_GA08N_FV01_Profile-SBE19plus_C-20241220T061609Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T191700Z_GA08N_FV01_Profile-SBE19plus_C-20240905T020802Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA08N/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T191700Z_GA08N_FV01_Profile-SBE19plus_C-20241220T054621Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T061700Z_GA09K_FV01_Profile-SBE19plus_C-20240205T004350Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T061700Z_GA09K_FV01_Profile-SBE19plus_C-20241220T061610Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T062600Z_GA09K_FV01_Profile-SBE19plus_C-20240905T020803Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T062600Z_GA09K_FV01_Profile-SBE19plus_C-20241220T054623Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T182200Z_GA09M_FV01_Profile-SBE19plus_C-20240205T004352Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T182200Z_GA09M_FV01_Profile-SBE19plus_C-20241220T061613Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T171300Z_GA09M_FV01_Profile-SBE19plus_C-20240905T020804Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA09M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T171300Z_GA09M_FV01_Profile-SBE19plus_C-20241220T054626Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA10J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T075800Z_GA10J_FV01_Profile-SBE19plus_C-20240205T004353Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA10J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T075800Z_GA10J_FV01_Profile-SBE19plus_C-20241220T061616Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA10J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T083300Z_GA10J_FV01_Profile-SBE19plus_C-20240905T020805Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA10J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T083300Z_GA10J_FV01_Profile-SBE19plus_C-20241220T054629Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11I/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T094000Z_GA11I_FV01_Profile-SBE19plus_C-20240205T004354Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11I/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T094000Z_GA11I_FV01_Profile-SBE19plus_C-20241220T061618Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11I/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T104000Z_GA11I_FV01_Profile-SBE19plus_C-20240905T020806Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11I/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T104000Z_GA11I_FV01_Profile-SBE19plus_C-20241220T054631Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T155900Z_GA11M_FV01_Profile-SBE19plus_C-20240205T004355Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T155900Z_GA11M_FV01_Profile-SBE19plus_C-20241220T061621Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T150400Z_GA11M_FV01_Profile-SBE19plus_C-20240905T020807Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA11M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T150400Z_GA11M_FV01_Profile-SBE19plus_C-20241220T054634Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA12H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T112200Z_GA12H_FV01_Profile-SBE19plus_C-20240205T004356Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA12H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T112200Z_GA12H_FV01_Profile-SBE19plus_C-20241220T061623Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA12H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T124700Z_GA12H_FV01_Profile-SBE19plus_C-20240905T020808Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA12H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T124700Z_GA12H_FV01_Profile-SBE19plus_C-20241220T054635Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA13M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T133500Z_GA13M_FV01_Profile-SBE19plus_C-20240205T004357Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA13M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T133500Z_GA13M_FV01_Profile-SBE19plus_C-20241220T061625Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA13M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T125000Z_GA13M_FV01_Profile-SBE19plus_C-20240905T020809Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA13M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T125000Z_GA13M_FV01_Profile-SBE19plus_C-20241220T054637Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA14F/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T145200Z_GA14F_FV01_Profile-SBE19plus_C-20240205T004358Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA14F/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T145200Z_GA14F_FV01_Profile-SBE19plus_C-20241220T061626Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA14F/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T114500Z_GA14F_FV01_Profile-SBE19plus_C-20240905T014525Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA14F/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T114500Z_GA14F_FV01_Profile-SBE19plus_C-20241220T060653Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA14F/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T165600Z_GA14F_FV01_Profile-SBE19plus_C-20240905T020810Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA14F/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T165600Z_GA14F_FV01_Profile-SBE19plus_C-20241220T054638Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15G/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T163500Z_GA15G_FV01_Profile-SBE19plus_C-20240205T004359Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15G/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T163500Z_GA15G_FV01_Profile-SBE19plus_C-20241220T061627Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15G/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T142800Z_GA15G_FV01_Profile-SBE19plus_C-20240905T014527Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15G/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T142800Z_GA15G_FV01_Profile-SBE19plus_C-20241220T060655Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15G/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T190800Z_GA15G_FV01_Profile-SBE19plus_C-20240905T020811Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15G/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T190800Z_GA15G_FV01_Profile-SBE19plus_C-20241220T054640Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T101300Z_GA15M_FV01_Profile-SBE19plus_C-20240905T020812Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA15M/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T101300Z_GA15M_FV01_Profile-SBE19plus_C-20241220T054642Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T181800Z_GA16H_FV01_Profile-SBE19plus_C-20240205T004400Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T181800Z_GA16H_FV01_Profile-SBE19plus_C-20241220T061628Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T163700Z_GA16H_FV01_Profile-SBE19plus_C-20240905T014528Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T163700Z_GA16H_FV01_Profile-SBE19plus_C-20241220T060656Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T211000Z_GA16H_FV01_Profile-SBE19plus_C-20240905T020813Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T211000Z_GA16H_FV01_Profile-SBE19plus_C-20241220T054643Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240923T192100Z_GA16H_FV01_Profile-SBE19plus_C-20241009T025858Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA16H/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240923T192100Z_GA16H_FV01_Profile-SBE19plus_C-20241220T055641Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T014200Z_GA18J_FV01_Profile-SBE19plus_C-20240205T004401Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T014200Z_GA18J_FV01_Profile-SBE19plus_C-20241220T061629Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T043100Z_GA18J_FV01_Profile-SBE19plus_C-20240905T014529Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T043100Z_GA18J_FV01_Profile-SBE19plus_C-20241015T012930Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240321T043100Z_GA18J_FV01_Profile-SBE19plus_C-20241015T013629Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240321T043100Z_GA18J_FV01_Profile-SBE19plus_C-20241220T060658Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240523T052600Z_GA18J_FV01_Profile-SBE19plus_C-20240905T020815Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240523T052600Z_GA18J_FV01_Profile-SBE19plus_C-20241220T054645Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T022900Z_GA18J_FV01_Profile-SBE19plus_C-20241009T025859Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA18J/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T022900Z_GA18J_FV01_Profile-SBE19plus_C-20241220T055645Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T032100Z_GA19K_FV01_Profile-SBE19plus_C-20240205T004403Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T032100Z_GA19K_FV01_Profile-SBE19plus_C-20241220T061631Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240319T014300Z_GA19K_FV01_Profile-SBE19plus_C-20240905T014530Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240319T014300Z_GA19K_FV01_Profile-SBE19plus_C-20241220T060700Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240523T081700Z_GA19K_FV01_Profile-SBE19plus_C-20240905T020816Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240523T081700Z_GA19K_FV01_Profile-SBE19plus_C-20241220T054646Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T041500Z_GA19K_FV01_Profile-SBE19plus_C-20241009T025901Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/GA19K/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T041500Z_GA19K_FV01_Profile-SBE19plus_C-20241220T055648Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL03/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T170700Z_JL03_FV01_Profile-SBE19plus_C-20240905T014531Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL03/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T170700Z_JL03_FV01_Profile-SBE19plus_C-20241220T060703Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL03/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T020600Z_JL03_FV01_Profile-SBE19plus_C-20240905T020817Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL03/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T020600Z_JL03_FV01_Profile-SBE19plus_C-20241220T054648Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL03/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T111500Z_JL03_FV01_Profile-SBE19plus_C-20241009T025903Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL03/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T111500Z_JL03_FV01_Profile-SBE19plus_C-20241220T055650Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL04/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T175600Z_JL04_FV01_Profile-SBE19plus_C-20240905T014532Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL04/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T175600Z_JL04_FV01_Profile-SBE19plus_C-20241220T060706Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL04/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T011300Z_JL04_FV01_Profile-SBE19plus_C-20240905T020819Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL04/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T011300Z_JL04_FV01_Profile-SBE19plus_C-20241220T054649Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL04/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T103300Z_JL04_FV01_Profile-SBE19plus_C-20241009T025905Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL04/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T103300Z_JL04_FV01_Profile-SBE19plus_C-20241220T055652Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL05/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T184900Z_JL05_FV01_Profile-SBE19plus_C-20240905T014534Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL05/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T184900Z_JL05_FV01_Profile-SBE19plus_C-20241220T060707Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL05/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T001700Z_JL05_FV01_Profile-SBE19plus_C-20240905T020820Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL05/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T001700Z_JL05_FV01_Profile-SBE19plus_C-20241220T054651Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL05/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T094400Z_JL05_FV01_Profile-SBE19plus_C-20241009T025907Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL05/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T094400Z_JL05_FV01_Profile-SBE19plus_C-20241220T055654Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL06/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T193400Z_JL06_FV01_Profile-SBE19plus_C-20240905T014535Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL06/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T193400Z_JL06_FV01_Profile-SBE19plus_C-20241220T060709Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL06/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T233700Z_JL06_FV01_Profile-SBE19plus_C-20240905T020822Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL06/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T233700Z_JL06_FV01_Profile-SBE19plus_C-20241220T054652Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL06/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T090500Z_JL06_FV01_Profile-SBE19plus_C-20241009T025909Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL06/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T090500Z_JL06_FV01_Profile-SBE19plus_C-20241220T055656Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL07/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T201600Z_JL07_FV01_Profile-SBE19plus_C-20240905T014536Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL07/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T201600Z_JL07_FV01_Profile-SBE19plus_C-20241220T060710Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL07/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T225300Z_JL07_FV01_Profile-SBE19plus_C-20240905T020824Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL07/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T225300Z_JL07_FV01_Profile-SBE19plus_C-20241220T054654Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL07/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T082400Z_JL07_FV01_Profile-SBE19plus_C-20241009T025910Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL07/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T082400Z_JL07_FV01_Profile-SBE19plus_C-20241220T055658Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T045300Z_JL09_FV01_Profile-SBE19plus_C-20240205T004404Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T045300Z_JL09_FV01_Profile-SBE19plus_C-20241220T061632Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T235300Z_JL09_FV01_Profile-SBE19plus_C-20240905T014537Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T235300Z_JL09_FV01_Profile-SBE19plus_C-20241220T060711Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T203500Z_JL09_FV01_Profile-SBE19plus_C-20240905T020825Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T203500Z_JL09_FV01_Profile-SBE19plus_C-20241220T054655Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T055400Z_JL09_FV01_Profile-SBE19plus_C-20241009T025913Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/JL09/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T055400Z_JL09_FV01_Profile-SBE19plus_C-20241220T055700Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM3MS/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T125200Z_SAM3MS_FV01_Profile-SBE19plus_C-20240205T004407Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM3MS/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231026T125200Z_SAM3MS_FV01_Profile-SBE19plus_C-20241220T061635Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM3MS/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T093000Z_SAM3MS_FV01_Profile-SBE19plus_C-20240905T014541Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM3MS/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240320T093000Z_SAM3MS_FV01_Profile-SBE19plus_C-20241220T060716Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM3MS/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T143200Z_SAM3MS_FV01_Profile-SBE19plus_C-20240905T020828Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM3MS/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240522T143200Z_SAM3MS_FV01_Profile-SBE19plus_C-20241220T054702Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM5CB/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T231800Z_SAM5CB_FV01_Profile-SBE19plus_C-20240205T004408Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM5CB/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231025T231800Z_SAM5CB_FV01_Profile-SBE19plus_C-20241220T061636Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM5CB/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T224300Z_SAM5CB_FV01_Profile-SBE19plus_C-20240905T020829Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM5CB/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240521T224300Z_SAM5CB_FV01_Profile-SBE19plus_C-20241220T054704Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM5CB/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240926T013000Z_SAM5CB_FV01_Profile-SBE19plus_C-20241009T025918Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM5CB/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240926T013000Z_SAM5CB_FV01_Profile-SBE19plus_C-20241220T055704Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T061100Z_SAM8SG_FV01_Profile-SBE19plus_C-20240205T004409Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231027T061100Z_SAM8SG_FV01_Profile-SBE19plus_C-20241220T061637Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T222500Z_SAM8SG_FV01_Profile-SBE19plus_C-20240905T014542Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240318T222500Z_SAM8SG_FV01_Profile-SBE19plus_C-20241220T060717Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T213200Z_SAM8SG_FV01_Profile-SBE19plus_C-20240905T020830Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240520T213200Z_SAM8SG_FV01_Profile-SBE19plus_C-20241220T054707Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T070600Z_SAM8SG_FV01_Profile-SBE19plus_C-20241009T025921Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAM8SG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240924T070600Z_SAM8SG_FV01_Profile-SBE19plus_C-20241220T055706Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAMUSG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T215100Z_SAMUSG_FV01_Profile-SBE19plus_C-20240205T011712Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAMUSG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T215100Z_SAMUSG_FV01_Profile-SBE19plus_C-20241220T053522Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAMUSG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T215400Z_SAMUSG_FV01_Profile-SBE19plus_C-20240207T043721Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/SAMUSG/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T215400Z_SAMUSG_FV01_Profile-SBE19plus_C-20241220T054140Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T210700Z_USG1_FV01_Profile-SBE19plus_C-20240205T011713Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T210700Z_USG1_FV01_Profile-SBE19plus_C-20241220T053523Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T232300Z_USG1_FV01_Profile-SBE19plus_C-20240207T043723Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T232300Z_USG1_FV01_Profile-SBE19plus_C-20241220T054141Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T213100Z_USG2_FV01_Profile-SBE19plus_C-20240205T011714Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T213100Z_USG2_FV01_Profile-SBE19plus_C-20241220T053525Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T230800Z_USG2_FV01_Profile-SBE19plus_C-20240207T043725Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T230800Z_USG2_FV01_Profile-SBE19plus_C-20241220T054143Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T223900Z_USG4_FV01_Profile-SBE19plus_C-20240205T011716Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T223900Z_USG4_FV01_Profile-SBE19plus_C-20241220T053526Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T211700Z_USG4_FV01_Profile-SBE19plus_C-20240207T043726Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T211700Z_USG4_FV01_Profile-SBE19plus_C-20241220T054144Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T225600Z_USG5_FV01_Profile-SBE19plus_C-20240205T011717Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20231122T225600Z_USG5_FV01_Profile-SBE19plus_C-20241220T053527Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T210100Z_USG5_FV01_Profile-SBE19plus_C-20240207T043727Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/USG5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240129T210100Z_USG5_FV01_Profile-SBE19plus_C-20241220T054145Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T000900Z_VB1S1_FV01_Profile-SBE19_C-20230710T010415Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S1/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T000900Z_VB1S1_FV01_Profile-SBE19plus_C-20250114T005651Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T005100Z_VB1S2_FV01_Profile-SBE19_C-20230710T010418Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S2/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T005100Z_VB1S2_FV01_Profile-SBE19plus_C-20250114T005655Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T034600Z_VB1S4_FV01_Profile-SBE19_C-20230710T010421Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T034600Z_VB1S4_FV01_Profile-SBE19_C-20230710T010422Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T034600Z_VB1S4_FV01_Profile-SBE19plus_C-20250114T005658Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T034600Z_VB1S4_FV01_Profile-SBE19plus_C-20250114T005700Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T054100Z_VB1S4_FV01_Profile-SBE19plus_C-20241015T003535Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T054100Z_VB1S4_FV01_Profile-SBE19plus_C-20250116T062047Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T054300Z_VB1S4_FV01_Profile-SBE19plus_C-20241015T002642Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S4/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T054300Z_VB1S4_FV01_Profile-SBE19plus_C-20250116T062045Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T043000Z_VB1S5_FV01_Profile-SBE19_C-20230710T010425Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T043000Z_VB1S5_FV01_Profile-SBE19_C-20230710T010426Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T043000Z_VB1S5_FV01_Profile-SBE19plus_C-20250114T005703Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T043000Z_VB1S5_FV01_Profile-SBE19plus_C-20250114T005704Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T062200Z_VB1S5_FV01_Profile-SBE19plus_C-20241015T003536Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T062200Z_VB1S5_FV01_Profile-SBE19plus_C-20250116T062049Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T062300Z_VB1S5_FV01_Profile-SBE19plus_C-20241015T002643Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VB1S5/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T062300Z_VB1S5_FV01_Profile-SBE19plus_C-20250116T062048Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T013800Z_VBM100_FV01_Profile-SBE19_C-20230710T010429Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T013800Z_VBM100_FV01_Profile-SBE19plus_C-20250114T005709Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T013900Z_VBM100_FV01_Profile-SBE19_C-20230710T010428Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20230623T013900Z_VBM100_FV01_Profile-SBE19plus_C-20250114T005707Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023500Z_VBM100_FV01_Profile-SBE19plus_C-20241015T003538Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023500Z_VBM100_FV01_Profile-SBE19plus_C-20250116T062051Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023700Z_VBM100_FV01_Profile-SBE19plus_C-20241015T002644Z.nc',
#  's3://imos-data/IMOS/ANMN/SA/VBM100/Biogeochem_profiles/IMOS_ANMN-SA_CDEFKOSTUZ_20240718T023700Z_VBM100_FV01_Profile-SBE19plus_C-20250116T062050Z.nc']

# %%
duplicates.index[0]
# Out:
# <Item id=IMOS_ANMN_SA_CJ1_Biogeochem_profiles_IMOS_ANMN-SA_CDEFKOSTUZ_20240521T081400Z_CJ1_FV01_Profile-SBE19plus_C-20240905T020756Z_nc>

# %% [markdown]
# ## Identify input files for creating a product
# For example the Moorings - Hourly time-series product is generated from hundreds of individual instrument-deployment files at each mooring site.
#
# Code adapted from [this script](https://github.com/aodn/python-aodndata/blob/master/aodndata/moorings/moorings_product_trigger.py).

# %%
INCLUDED_VARIABLES = {'TEMP', 'PSAL', 'CPHL', 'CHLF', 'CHLU', 'TURB', 'DOX1', 'DOX2', 'DOXS', 'PAR', 'VCUR'}
def pivot_variables(df: pd.DataFrame) -> pd.DataFrame:
    """Rearrange the file-list data frame so that each row lists one variable only
    (multiple rows per file where needed)
    """
    assert 'variables' in df.columns
    files_vars = []
    for row in df.itertuples():
        variables = set(row.variables.keys()) & INCLUDED_VARIABLES
        files_vars.extend((row.Index, v) for v in variables)

    files_vars = pd.DataFrame(files_vars, columns=['i', 'variable']).set_index('i')

    return df.drop(columns='variables').join(files_vars, how='right')

# %%
possible_sites= ['NRSDAR', 'NRSESP', 'NRSKAI', 'NRSMAI', 'NRSNIN', 'NRSNSI',
                 'NRSPHB', 'NRSROT', 'NRSYON', 'SEQ200', 'SEQ400', 'DARBGF']
aggregated_uuid = "moorings-aggregated-timeseries-product"
hourly_uuid = "efd8201c-1eca-412e-9ad2-0534e96cea14"
for site_code in possible_sites:
    site_files = df[df['site_code'] == site_code]
    source_index = site_files['file_version'] == 'Level 1 - Quality Controlled Data'

    # We will need to filter out aggregated products once we index them.
    # Can be done filtering by collection id, possibly after going through the
    # collections to see which ones are aggregations
    source_files = site_files.loc[source_index, ['created', 'cube:variables']].rename(
        columns={'cube:variables': 'variables'}
    )
    source_files = pivot_variables(source_files)

    # Aggregated products
    collection = catalog.get_child(aggregated_uuid, recursive=True)
    items = collection.get_items(recursive=True)
    # Convert to DataFrame
    aggregated_files = pd.DataFrame.from_dict(
        {item: item.properties | {"collection": item.collection_id} for item in items},
        orient="index",
    )
    aggregated_files = aggregated_files[['created', 'cube:variables']].rename(
        columns={'cube:variables': 'variables'}
    )
    aggregated_files = pivot_variables(aggregated_files)

    # Hourly products
    collection = catalog.get_child(hourly_uuid, recursive=True)
    items = collection.get_items(recursive=True)
    # Convert to DataFrame
    hourly_files = pd.DataFrame.from_dict(
        {item: item.properties | {"collejction": item.collection_id} for item in items},
        orient="index",
    )
    hourly_files = hourly_files[['created']]

    # when were data for each variable updated?
    vars_updated = source_files.groupby('variable').created.max()
    vars_updated.name = 'source_updated'
    aggregated_files = aggregated_files.join(vars_updated, on='variable', how='right')

    # which variables have newer data than the product, or missing product?
    new_vars = aggregated_files[np.logical_or(aggregated_files.created < aggregated_files.source_updated,
                                                aggregated_files.created.isna()
                                                )]
    new_vars = set(new_vars.variable)

    # reprocess hourly products if newer source files exist, or product files missing?
    products_updated = hourly_files.created.max()
    process_hourly = any(source_files.created > products_updated) or hourly_files.empty

    if len(new_vars) == 0 and not process_hourly:
        print(f"{site_code}: All products up to date")
    else:
        # products to generate
        # VCUR is used as a proxy for all velocity variables - if included, need to handle separately
        products = set()
        if 'VCUR' in new_vars:
            new_vars.remove('VCUR')
            products.update({'velocity_aggregated', 'velocity_hourly'})
        if new_vars:
            products.add('aggregated')
        if process_hourly:
            # gridded is created from hourly, so need to process both
            products.update({'hourly', 'gridded'})

        # create manifest
        manifest = {'site_code': site_code,
                    'variables': list(new_vars),
                    'products': list(products)
                    }
        print(manifest)
# Out:
# NRSDAR: All products up to date
# NRSESP: All products up to date
# NRSKAI: All products up to date
# NRSMAI: All products up to date
# NRSNIN: All products up to date
# NRSNSI: All products up to date
# NRSPHB: All products up to date
# NRSROT: All products up to date
# NRSYON: All products up to date
# SEQ200: All products up to date
# SEQ400: All products up to date
# DARBGF: All products up to date
