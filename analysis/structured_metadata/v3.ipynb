# %%
import orjson
import genson
import natsort
import rich
from data_index.iceberg_config import S3TablesCatalogConfig, IcebergTableConfig

# %%
# --- Sinks config ---
data_index_catalog_config = S3TablesCatalogConfig(
    region="ap-southeast-2",
    arn="arn:aws:s3tables:ap-southeast-2:704910415367:bucket/data-index",
)

structured_table = IcebergTableConfig(
    catalog_config=data_index_catalog_config,
    namespace="data_index",
    table_name=f"structured_metadata_v3",
).load()

unstructured_table = IcebergTableConfig(
    catalog_config=data_index_catalog_config,
    namespace="data_index",
    table_name="unstructured_metadata_v3",
).load()

# %%
# Read into memory as polars.DataFrame
sdf = structured_table.scan().to_polars()
udf = unstructured_table.scan().to_polars()
display(sdf)
display(udf)
# Out:
# shape: (100, 32)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ bucket    ┆ key       ┆ version_i ┆ hash      ┆ … ┆ variables ┆ standard_ ┆ file_form ┆ facility │
# │ ---       ┆ ---       ┆ d         ┆ ---       ┆   ┆ ---       ┆ names     ┆ at        ┆ ---      │
# │ str       ┆ str       ┆ ---       ┆ str       ┆   ┆ list[str] ┆ ---       ┆ ---       ┆ str      │
# │           ┆           ┆ str       ┆           ┆   ┆           ┆ list[str] ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ imos-data ┆ IMOS/ANMN ┆ OZ_BvANDI ┆ a158a3f3e ┆ … ┆ ["SSS",   ┆ ["latitud ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ /AM/GBRWI ┆ H4YGsfkON ┆ 2b3b02565 ┆   ┆ "SSTI", … ┆ e", "long ┆ LASSIC    ┆          │
# │           ┆ S/CO2/rea ┆ 5vRdvKR6h ┆ 7227634e8 ┆   ┆ "XCO2_WAT ┆ itude", … ┆           ┆          │
# │           ┆ l-t…      ┆ lJ2…      ┆ 594…      ┆   ┆ ER_…      ┆ "t…       ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ KaVQ0elQM ┆ 8757bf2ee ┆ … ┆ ["SSS",   ┆ ["latitud ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ /AM/GBRWI ┆ XcePt7MUG ┆ 020635d09 ┆   ┆ "SSTI", … ┆ e", "long ┆ LASSIC    ┆          │
# │           ┆ S/CO2/rea ┆ vuTHN.6z_ ┆ 83535e005 ┆   ┆ "XCO2_WAT ┆ itude", … ┆           ┆          │
# │           ┆ l-t…      ┆ mr8…      ┆ d15…      ┆   ┆ ER_…      ┆ "t…       ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ o.A21XCYE ┆ a26909eb0 ┆ … ┆ ["SSS",   ┆ ["latitud ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ /AM/NRSKA ┆ G9DrXPWku ┆ 0c710f8bc ┆   ┆ "SSTI", … ┆ e", "long ┆ LASSIC    ┆          │
# │           ┆ I/CO2/rea ┆ wKoSD.x0B ┆ 4ee7154d3 ┆   ┆ "XCO2_WAT ┆ itude", … ┆           ┆          │
# │           ┆ l-t…      ┆ t_w…      ┆ 888…      ┆   ┆ ER_…      ┆ "t…       ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ rHVXerSg. ┆ 9375d1e95 ┆ … ┆ ["SSS",   ┆ ["latitud ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ /AM/NRSKA ┆ R2n_2Khf9 ┆ b5d8117e2 ┆   ┆ "SSTI", … ┆ e", "long ┆ LASSIC    ┆          │
# │           ┆ I/CO2/rea ┆ TL6JYny79 ┆ c52c2764e ┆   ┆ "XCO2_WAT ┆ itude", … ┆           ┆          │
# │           ┆ l-t…      ┆ j_I…      ┆ 9b5…      ┆   ┆ ER_…      ┆ "t…       ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ S8BPjB4zp ┆ 4aec2abf0 ┆ … ┆ ["SSS",   ┆ ["latitud ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ /AM/NRSMA ┆ PEt4ef.FK ┆ b8e467cfb ┆   ┆ "SSTI", … ┆ e", "long ┆ LASSIC    ┆          │
# │           ┆ I/CO2/rea ┆ glnhKsuMC ┆ ae2d7e2cb ┆   ┆ "XCO2_WAT ┆ itude", … ┆           ┆          │
# │           ┆ l-t…      ┆ 9d0…      ┆ 592…      ┆   ┆ ER_…      ┆ "t…       ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ imos-data ┆ IMOS/ANMN ┆ M854Ks5BO ┆ ed654a383 ┆ … ┆ ["BOT_DEP ┆ ["depth", ┆ NETCDF4   ┆ ANMN     │
# │           ┆ /NRS/NRSD ┆ ujXc0JmwD ┆ b9e0b7736 ┆   ┆ TH",      ┆ "latitude ┆           ┆          │
# │           ┆ AR/Biogeo ┆ KmRAIShea ┆ d7da5754c ┆   ┆ "CHLF", … ┆ ", …      ┆           ┆          │
# │           ┆ che…      ┆ 3CC…      ┆ d6c…      ┆   ┆ "TEMP_…   ┆ "time"…   ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ rrWNiteL8 ┆ e5a675052 ┆ … ┆ ["BOT_DEP ┆ ["depth", ┆ NETCDF4   ┆ ANMN     │
# │           ┆ /NRS/NRSD ┆ XtuYSnOCH ┆ 0534662d8 ┆   ┆ TH",      ┆ "latitude ┆           ┆          │
# │           ┆ AR/Biogeo ┆ JT92UifeI ┆ b4e30024f ┆   ┆ "CHLF", … ┆ ", …      ┆           ┆          │
# │           ┆ che…      ┆ 07Z…      ┆ c3e…      ┆   ┆ "TEMP_…   ┆ "time"…   ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ vSPNZEF7Z ┆ 38aee221c ┆ … ┆ ["BOT_DEP ┆ ["depth", ┆ NETCDF4   ┆ ANMN     │
# │           ┆ /NRS/NRSD ┆ 5oG.XkhJ5 ┆ 22fbb7eeb ┆   ┆ TH",      ┆ "latitude ┆           ┆          │
# │           ┆ AR/Biogeo ┆ JwFHCVnrx ┆ 76c233b44 ┆   ┆ "CHLF", … ┆ ", …      ┆           ┆          │
# │           ┆ che…      ┆ K1x…      ┆ f2b…      ┆   ┆ "TEMP_…   ┆ "time"…   ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ 1n4bD2kuy ┆ 5202334a4 ┆ … ┆ ["BOT_DEP ┆ ["depth", ┆ NETCDF4   ┆ ANMN     │
# │           ┆ /NRS/NRSD ┆ RDLCICprn ┆ 75ecb4900 ┆   ┆ TH",      ┆ "latitude ┆           ┆          │
# │           ┆ AR/Biogeo ┆ p0RWsGI3i ┆ 83931a395 ┆   ┆ "CHLF", … ┆ ", …      ┆           ┆          │
# │           ┆ che…      ┆ jxk…      ┆ f9e…      ┆   ┆ "TEMP_…   ┆ "time"…   ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN ┆ PMafznwLg ┆ 5fa49e00d ┆ … ┆ ["BOT_DEP ┆ ["depth", ┆ NETCDF4   ┆ ANMN     │
# │           ┆ /NRS/NRSD ┆ KXJj0D87A ┆ e88961664 ┆   ┆ TH",      ┆ "latitude ┆           ┆          │
# │           ┆ AR/Biogeo ┆ _UYlrUmox ┆ bd534fb9a ┆   ┆ "CHLF", … ┆ ", …      ┆           ┆          │
# │           ┆ che…      ┆ BNb…      ┆ 524…      ┆   ┆ "TEMP_…   ┆ "time"…   ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# shape: (100, 8)
# ┌───────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┬──────────┐
# │ bucket    ┆ key        ┆ version_id ┆ hash       ┆ schema_ver ┆ metadata  ┆ file_form ┆ facility │
# │ ---       ┆ ---        ┆ ---        ┆ ---        ┆ sion       ┆ ---       ┆ at        ┆ ---      │
# │ str       ┆ str        ┆ str        ┆ str        ┆ ---        ┆ str       ┆ ---       ┆ str      │
# │           ┆            ┆            ┆            ┆ i64        ┆           ┆ str       ┆          │
# ╞═══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪══════════╡
# │ imos-data ┆ IMOS/ANMN/ ┆ OZ_BvANDIH ┆ a158a3f3e2 ┆ 3          ┆ {"global_ ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ AM/GBRWIS/ ┆ 4YGsfkON5v ┆ b3b0256572 ┆            ┆ attrs":   ┆ LASSIC    ┆          │
# │           ┆ CO2/real-t ┆ RdvKR6hlJ2 ┆ 27634e8594 ┆            ┆ {"project ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ ": "…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ KaVQ0elQMX ┆ 8757bf2ee0 ┆ 3          ┆ {"global_ ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ AM/GBRWIS/ ┆ cePt7MUGvu ┆ 20635d0983 ┆            ┆ attrs":   ┆ LASSIC    ┆          │
# │           ┆ CO2/real-t ┆ THN.6z_mr8 ┆ 535e005d15 ┆            ┆ {"project ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ ": "…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ o.A21XCYEG ┆ a26909eb00 ┆ 3          ┆ {"global_ ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ AM/NRSKAI/ ┆ 9DrXPWkuwK ┆ c710f8bc4e ┆            ┆ attrs":   ┆ LASSIC    ┆          │
# │           ┆ CO2/real-t ┆ oSD.x0Bt_w ┆ e7154d3888 ┆            ┆ {"project ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ ": "…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ rHVXerSg.R ┆ 9375d1e95b ┆ 3          ┆ {"global_ ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ AM/NRSKAI/ ┆ 2n_2Khf9TL ┆ 5d8117e2c5 ┆            ┆ attrs":   ┆ LASSIC    ┆          │
# │           ┆ CO2/real-t ┆ 6JYny79j_I ┆ 2c2764e9b5 ┆            ┆ {"project ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ ": "…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ S8BPjB4zpP ┆ 4aec2abf0b ┆ 3          ┆ {"global_ ┆ NETCDF3_C ┆ ANMN     │
# │           ┆ AM/NRSMAI/ ┆ Et4ef.FKgl ┆ 8e467cfbae ┆            ┆ attrs":   ┆ LASSIC    ┆          │
# │           ┆ CO2/real-t ┆ nhKsuMC9d0 ┆ 2d7e2cb592 ┆            ┆ {"project ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ ": "…     ┆           ┆          │
# │ …         ┆ …          ┆ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …        │
# │ imos-data ┆ IMOS/ANMN/ ┆ M854Ks5BOu ┆ ed654a383b ┆ 3          ┆ {"global_ ┆ NETCDF4   ┆ ANMN     │
# │           ┆ NRS/NRSDAR ┆ jXc0JmwDKm ┆ 9e0b7736d7 ┆            ┆ attrs":   ┆           ┆          │
# │           ┆ /Biogeoche ┆ RAIShea3CC ┆ da5754cd6c ┆            ┆ {"toolbox ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ _inp…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ rrWNiteL8X ┆ e5a6750520 ┆ 3          ┆ {"global_ ┆ NETCDF4   ┆ ANMN     │
# │           ┆ NRS/NRSDAR ┆ tuYSnOCHJT ┆ 534662d8b4 ┆            ┆ attrs":   ┆           ┆          │
# │           ┆ /Biogeoche ┆ 92UifeI07Z ┆ e30024fc3e ┆            ┆ {"toolbox ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ _inp…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ vSPNZEF7Z5 ┆ 38aee221c2 ┆ 3          ┆ {"global_ ┆ NETCDF4   ┆ ANMN     │
# │           ┆ NRS/NRSDAR ┆ oG.XkhJ5Jw ┆ 2fbb7eeb76 ┆            ┆ attrs":   ┆           ┆          │
# │           ┆ /Biogeoche ┆ FHCVnrxK1x ┆ c233b44f2b ┆            ┆ {"toolbox ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ _inp…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ 1n4bD2kuyR ┆ 5202334a47 ┆ 3          ┆ {"global_ ┆ NETCDF4   ┆ ANMN     │
# │           ┆ NRS/NRSDAR ┆ DLCICprnp0 ┆ 5ecb490083 ┆            ┆ attrs":   ┆           ┆          │
# │           ┆ /Biogeoche ┆ RWsGI3ijxk ┆ 931a395f9e ┆            ┆ {"toolbox ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ _inp…     ┆           ┆          │
# │ imos-data ┆ IMOS/ANMN/ ┆ PMafznwLgK ┆ 5fa49e00de ┆ 3          ┆ {"global_ ┆ NETCDF4   ┆ ANMN     │
# │           ┆ NRS/NRSDAR ┆ XJj0D87A_U ┆ 88961664bd ┆            ┆ attrs":   ┆           ┆          │
# │           ┆ /Biogeoche ┆ YlrUmoxBNb ┆ 534fb9a524 ┆            ┆ {"toolbox ┆           ┆          │
# │           ┆ …          ┆ …          ┆ …          ┆            ┆ _inp…     ┆           ┆          │
# └───────────┴────────────┴────────────┴────────────┴────────────┴───────────┴───────────┴──────────┘

# %%
# Construct generator
metadata = (orjson.loads(metadata) for metadata in udf["metadata"])

# Build schema
schema_builder = genson.SchemaBuilder()
for metadata in metadata:
    schema_builder.add_object(metadata)

# Extract schema
schema = schema_builder.to_schema()

# %%
# Sort global attribute keys naturally (human-like)
sorted_global_attribute_keys = natsort.natsorted(
    seq=[k for k in schema["properties"]["global_attrs"]["properties"]],
    alg=natsort.IGNORECASE,
)
print(sorted_global_attribute_keys)

# %%
# Tuning parameters
SIMILARITY_THRESHOLD = 80
# Using token_sort_ratio handles underscores and word order swaps well
SCORER = thefuzz.fuzz.token_sort_ratio 

clusters = []
visited = set()

for key in sorted_global_attribute_keys:
    if key in visited:
        continue
    
    # Find all items in the list that match the current key above our threshold
    matches = thefuzz.process.extractBests(
        query=key, 
        choices=sorted_global_attribute_keys, 
        scorer=SCORER, 
        score_cutoff=SIMILARITY_THRESHOLD
    )
    
    # Filter matches to only include keys we haven't clustered yet
    current_cluster = [match[0] for match in matches if match[0] not in visited]
    
    if current_cluster:
        clusters.append(current_cluster)
        # Mark all keys in this cluster as visited so they aren't processed again
        visited.update(current_cluster)

# Print the resulting list of lists
import pprint
pprint.pprint(clusters)
